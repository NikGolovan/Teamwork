# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data_devoir1.csv", header = 1, index_col="Mois")
#data
data1 = data[["Tour de France: (France)" ,"Ligue 1: (France)","Internationaux de France de tennis: (France)","Formule 1: (France)"]]
data1
# Out:
#          Tour de France: (France)  Ligue 1: (France)  \
# Mois
# 2004-01                         2                  5
# 2004-02                         2                  6
# 2004-03                         2                  6
# 2004-04                         2                  6
# 2004-05                         3                  9
# 2004-06                         7                  6
# 2004-07                        81                  6
# 2004-08                         2                 10
# 2004-09                         1                  8
# 2004-10                         2                  7
# 2004-11                         2                  6
# 2004-12                         1                  6
# 2005-01                         1                  8
# 2005-02                         1                  7
# 2005-03                         1                  7
# 2005-04                         2                  7
# 2005-05                         2                  8
# ...

# %%
import seaborn as sns
#sns.set(style="whitegrid", font_scale=1.2)

data1.plot(kind="area", rot=90,grid=False)
pl= plt.gcf()
pl.set_size_inches(10, 10)
pl
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
data1.columns
# Out:
# Index(['Tour de France: (France)', 'Ligue 1: (France)',
#        'Internationaux de France de tennis: (France)', 'Formule 1: (France)'],
#       dtype='object')

# %%
plt.plot(data1['Tour de France: (France)'])

#ax.set_xlabel("hdhfbvdh")
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
