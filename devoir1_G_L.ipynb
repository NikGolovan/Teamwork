# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# on crée une variable et on y affectue les données lues du fichier data_devoir1.csv 
data = pd.read_csv("data_devoir1.csv", header = 1, index_col = "Mois")


graphe = sns.set(style = "whitegrid", font_scale = 1.2, rc={'figure.figsize':(17, 12.50)})
pl = data.plot(kind = "area", rot = 90, grid = False)
pl.set(ylabel = "Intérêt pour le sport \n (unités arbitraires)")


sns.plt.show()
# Out:
# /srv/conda/lib/python3.6/site-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
